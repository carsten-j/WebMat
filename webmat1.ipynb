# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import seaborn as sns
sns.set()
import sympy as sp

# %% [markdown]
# # Integration
# Lad funktionen $f$ være givet ved

# %%
def f(x):
    return 1/2 * x

# %% [markdown]
# Funktionen $F$ kaldes en stamfunktion for $f$, hvis $F'(x)=f(x)$. Stamfunktionen er givet ved det ubestemte integral $F(x)=\int f(x) \,dx$.

# %%
a = 2
b = 8
x = np.linspace(a, b, 100)
plt.plot(x, f(x))
plt.show()

# %%
x = sp.Symbol('x')
C = sp.Symbol('C')
integ = sp.integrate(f(x), x, manual=True)
integ + C
# Out:
# C + 0.25*x**2

# %%
val, err = integrate.quad(f, 2, 8)
print(val,err)
# Out:
# 15.0 1.6653345369377348e-13

# %%
k = sp.Symbol('k')

# %%
H =

# %%
H
# Out:
# -0.25*k**3 + 3.75*k**2 - 12.0*k + 11.0

# %%
type(H.subs(k, 5).evalf() + 5)
# Out:
# sympy.core.numbers.Float

# %%
def q(y):
    return H.subs(x, y).evalf() - 2.5

# %%
y = sp.Symbol('y')
sp.solve([y >= 2, y <= 8, q(y)], y)
# Out:
# (2 <= y) & (y <= 8) & (Eq(k, 1.0) | Eq(k, 3.12701665379258) | Eq(k, 10.8729833462074))

# %%
sp.solveset(q(y), domain=sp.Interval(2, 8))
# Out:
# FiniteSet(3.12701665379258)

# %%
y = np.linspace(2, 8, 120)

# %%
plt.plot(y, f(y), 'g')
plt.plot(y, g(y), 'r')
plt.show()

# %%
import math
def foo(x):
    return (x**2) * np.exp(x)

# %%
z = np.linspace(-10, 10, 100)

# %%
plt.plot(z, foo(z))
plt.show()

# %%
foo(0.1)
# Out:
# 0.011051709180756479

# %%
G=sp.diff(x**2 * sp.exp(x))

# %%
def r(y):
    return G.subs(x, y).evalf()

# %%
y = sp.Symbol('y')
sp.solve(r(y), y)
# Out:
# [-2.00000000000000, 0.0]

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.sin(math.pi/4)
# Out:
# 0.7071067811865475

# %%
A = 2
b = 1
c = 1
def p(x):
    return A * np.sin(b*x) + c

# %%
t = np.linspace(0, 20, 100)

# %%
plt.plot(t, p(t))
plt.show()

# %%
p(math.pi/4)
# Out:
# 2.414213562373095

# %%
2*np.sin(100)
2*np.cos(100)
# Out:
# 1.724637744575368

# %%
x = [2*np.sin(100), 2*np.cos(100)]

# %%
y = [3*np.sin(40), 3*np.cos(40)]

# %%
np.dot(x,y)
# Out:
# -5.714477882490938

# %%
x[0]*y[0]
# Out:
# -2.2637982192326644

# %%
x[1]*y[1]
# Out:
# -3.4506796632582737

# %%
x = np.linspace(-15, 40, 100)
z = np.piecewise(x, [(x >= -15) * (x <= 0), (x > 0) * (x <= 44)], [6, lambda x: np.sqrt(-x**2 + 52*x +36)])

# %%
plt.plot(x,z)
plt.show()

# %%
x1 = lambda x: -2*x +52
x2 = lambda x: np.sqrt(-x**2 + 52*x +36)
x3 = lambda x: (x1(x) / (2* x2(x)) )
x4 = lambda x: np.sqrt(x3(x)**2 + 1)
quad(x4, 0, 44)
# Out:
# (55.6184910829101, 1.1475825000042871e-09)

# %%
import math
x=sp.Symbol('x')
F=sp.diff(sp.sqrt(-x**2 + 52*x +36))

# %%
F
# Out:
# (26 - x)/sqrt(-x**2 + 52*x + 36)

# %%
f = sp.lambdify(x, F)

# %%
f(3)
# Out:
# 1.7002089231955175

# %%
from scipy.integrate import quad
import sympy as sp
import numpy as np

# %%
def f(x):
    return 1/2 * x

# %%
# Numerisk integration
res = quad(f, 2, 8)
print(res)
# Out:
# (15.0, 1.6653345369377348e-13)

# %%
x = sp.Symbol('x')
a = sp.Symbol('a')
b = sp.Symbol('b')

integ = sp.Integral(f(x), (x,a,b))
integ
# Out:
# Integral(0.5*x, (x, a, b))

# %%
integ.doit()
# Out:
# -0.25*a**2 + 0.25*b**2
